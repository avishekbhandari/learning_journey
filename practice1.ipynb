# %%
my_data = [10, 15, 20, 25]

# %%
sum(my_data)
# Out:
# 70

# %%
min(my_data)
# Out:
# 10

# %%
max(my_data)
# Out:
# 25

# %%
my_data.append(30)
# appends - add items at the end of the list always

# %%
my_data
# Out:
# [5, 10, 30]

# %% [markdown]
# POP

# %%
my_data.pop()
# POP removes and returns the removed element from the list.
# Out:
# 15

# %%
data = [10,20,30,40]

# %%
data.pop(1)
#we can pass index in the POP but not in append
# Out:
# 20

# %%
data
# Out:
# [10, 30, 40]

# %%
data.insert(0, 5)
# insert can add element at any specific index

# %%
data
# Out:
# [5, 10, 30, 40]

# %%
number = [60,70,80,90]

# %%
number[1:4]
# slicing start and end indexing
# Out:
# [70, 80, 90]

# %%
number[0:]
# slicing to end
# Out:
# [60, 70, 80, 90]

# %%
number[:3] 
# slicing from start
# Out:
# [60, 70, 80]

# %%
number[::1]
# slicing using step
# Out:
# [60, 70, 80, 90]

# %%
number[::2]
# Out:
# [60, 80]

# %%
number[::3]
# Out:
# [60, 90]

# %%
number
# Out:
# [60, 70, 80, 90]

# %%
number[1]
# Out:
# 70

# %%
number[-1]
# last element is -1 negative indexing
# Out:
# 90

# %%
number[-3:]
# using negative indexing to get last three elements
# Out:
# [70, 80, 90]
