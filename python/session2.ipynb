# %%
name = ["avi", "shyam", "hari"]

# %%
marks = [20, 50, 30, 90]

# %%
tuple(zip(name,marks))
#makes tuple
# Out:
# (('avi', 20), ('shyam', 50), ('hari', 30))

# %%
list(zip(name,marks))
# zip retuns tuple bcoz each pair is stored as an immutable record(tuple)
# Out:
# [('t', 20), ('r', 50), ('i', 30), ('v', 90)]

# %%
coders = [('avi', 20), ('shyam', 50), ('hari', 30)]

# %%
code, scores = zip(*coders)
print(code)
print(scores)
# this is unzipping
# Out:
# ('avi', 'shyam', 'hari')
# (20, 50, 30)

# %%
students = ['alex', 'bocb', 'triv']
scores = [85, 92,78]
#giving two names and zipping
for name, score in zip(students, scores):
    print(name, score)
# Out:
# alex 85
# bocb 92
# triv 78

# %%
A = [1,2,3]
B = [4,5,6]
C = [7,8,9]
list(zip(A,B,C))
# zip can take more than two list
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]

# %%
my_set = {1,2,3,4,5,6,3,4}
my_set
# we passed duplicate values, set removed duplicates automatically
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.add(7)
# add insert the new elements into set at last

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.add(3)
# if value exist already and u try to add it, it will get ignored

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.remove(1)
my_set
# remove - delete specific element from set
# Out:
# {3, 4, 5, 6, 7}

# %%
my_set.remove(10)
my_set
# gives key error if u try to remove element which is not there in set
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 my_set.remove(10)
#       2 my_set
#       3 # gives key error if u try to remove element which is not there in set
#
# KeyError: 10

# %%
my_set.discard(11)
my_set
# using discard get no key error
# Out:
# {3, 4, 5, 6, 7}

# %%
len(my_set)
# Out:
# 5

# %%
max(my_set)
# Out:
# 7

# %%
min(my_set)
# Out:
# 3

# %%
sum(my_set)
# Out:
# 25

# %% [markdown]
# union in set
# union combines all unique values including duplicates (unique elements with duplicates)

# %%
A = {1,2,3}
B = {3,4,5}
A|B #union
# Out:
# {1, 2, 3, 4, 5}

# %%
A&B # intersection- gives common element
# Out:
# {3}

# %%
A-B # difference - gives unique element from A but not B
# Out:
# {1, 2}

# %%
B-A
# Out:
# {4, 5}

# %%
# symmetric difference ^ 
A^B # elements present in either set but not in both (unique element without duplicates)
# Out:
# {1, 2, 4, 5}

# %%
# remove duplicate from list
pages = [1,2,3,2,3]
my_pages = set(pages)
my_pages
# Out:
# {1, 2, 3}

# %%
my_pages[0] # bcoz sets are unordered (no indexing like list) - typeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 my_pages[0]
#
# TypeError: 'set' object is not subscriptable

# %%
coders = {[1,2], [3,4]} # we cannot store list inside set bcoz list are mutable and is not allowed
coders
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 coders = {[1,2], [3,4]}
#       2 coders
#
# TypeError: unhashable type: 'list'

# %%
coders = { (1,2), (3,4)} # tuples are allowed bcoz they are not mutable
coders
# Out:
# {(1, 2), (3, 4)}

# %%
# whenever we need unique values we can use set

# %%
datas= [1,2,2,3,4,4]
new_data =set(datas) # removes the duplication of list
new_data
# Out:
# {1, 2, 3, 4}

# %%
new_data.add(10)
new_data
# Out:
# {1, 2, 3, 4, 10}

# %%
new_data.discard(11)

# %%
new_data.remove(11)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 new_data.remove(11)
#
# KeyError: 11

# %%
new_data.discard(2)
new_data
# Out:
# {1, 3, 4, 10}

# %%
D = {2,3,4,9}
E = {9, 10, 11}

# %%
# count unique elements in list
list = [1,2,2,3,3,4,5]
unique_list = len(set(list))
unique_list
# set remove duplicates from list and len counts the elements
# Out:
# 5

# %%
# to check element is there or not, very fast
# returns boolean values
print(3 in list)
# Out:
# True

# %%
# converst set to list

my_dbs = {1, 2, 3}
my_list = list(my_dbs)

print(my_list)
# error has come because we have used list as an variable in above lines
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 4
#       1 # converst set to list
#       3 my_dbs = {1, 2, 3}
# ----> 4 my_list = list(my_dbs)
#       6 print(my_list)
#       7 # error has come because we have used list as an variable in above lines
#
# TypeError: 'list' object is not callable

# %%
this_dict = {
    "name" : "Avishek",
    "class" : "BDE",
    "year" : 2026,
    "year" : 2020
}
this_dict
# Out:
# {'name': 'Avishek', 'class': 'BDE', 'year': 2020}

# %%
this_dict["name"]
# Out:
# 'Avishek'

# %%
student = {
    "name" : "avi",
    "years" : 2027,
    "Course" : "DE"
}
student
# Out:
# {'name': 'avi', 'years': 2027, 'Course': 'DE'}

# %%
# key - key is like a label or name use to identify the data

# %%
student["name"] # we use key to get the value
# Out:
# 'avi'

# %%
student["yea"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 student["yea"]
#
# KeyError: 'yea'

# %%
print(student.get("city"))
# safe way to check if any key is present in dictionary or not
# Out:
# None

# %%
student.pop("years") # pop removes key value pair using key
# Out:
# 2027

# %%
student.pop("salary", "not found")
# Out:
# 'not found'

# %%
# length of dictionary

# %%
len(student) # len function gives numberof key and value pairs, counts pairs (key + value)
# Out:
# 2

# %%
student.clear() # removes everything form dictionary but variable still exist

# %%
student
# Out:
# {}

# %%
# this is passing values after clear
student["name"] = "vaxo"
student["year"] = 20256
student
# Out:
# {'name': 'vaxo', 'year': 20256}

# %%
student["year"] = 2005 # update value
student
# Out:
# {'name': 'vaxo', 'year': 2005}

# %%
# important properties
dict = {
    "name" : "kaku",
    "name" : "kris" # last value overwrites
}
dict
# Out:
# {'name': 'kris'}

# %%
# values can be duplicate
data1 = {
    "a" : 10,
    "b" : 10
}
data1
# Out:
# {'a': 10, 'b': 10}

# %%
employee = {
    "id" : 121, 
    "name" : "jackk",
    "salary" : 200000
}
employee["name"]
# Out:
# 'jackk'

# %%
data3 = {
    1 : "one"
}
data3
# Out:
# {1: 'one'}

# %%
data3[1]
# Out:
# 'one'
