# %%
num = [25,35,65,75]

# %%
len(num)
# Out:
# 4

# %%
num.append(85)

# %%
num.append(95)

# %%
num
# Out:
# [25, 35, 65, 75, 85, 95]

# %%
nums = (60, 70, 80, 90)

# %%
nums[1:4]
# Out:
# (70, 80, 90)

# %%
names = ["avi", "shyam", "hari"]

# %%
list(zip(num,names))
# Out:
# [(25, 'avi'), (35, 'shyam'), (65, 'hari')]

# %%
text = "avishek"

# %%
text.isalpha()
# Out:
# True
