# %% [markdown]
# Q1. List is the collection of elements which are ordered and mutable and tuple is ordered but not mutable.
#     Lists are used for dynamic data and tuples are used for fixed data.

# %%
my_list = [ "Avi", "Shyam", "Krish", "Bob"]
my_tuple = (10, 20, 30, 40)
my_list[0]
# Out:
# 'Avi'

# %%
my_list.append("Bahadur") # append add elements at last
my_list
# Out:
# ['Avi', 'Shyam', 'Krish', 'Bob', 'Bahadur']

# %%
my_list.insert(1, "Hari") #insert add elements at specific position
my_list
# Out:
# ['Avi', 'Hari', 'Shyam', 'Krish', 'Bob', 'Bahadur']

# %%
my_list.pop()
# Out:
# 'Bahadur'

# %%
my_list
# Out:
# ['Avi', 'Shyam', 'Krish', 'Bob']

# %%
my_list.pop()
# Out:
# 'Bob'

# %%
my_list
# Out:
# ['Avi', 'Shyam', 'Krish']

# %%
tuple(my_list)# converting list to tuple
# Out:
# ('Avi', 'Shyam', 'Krish')

# %%
my_tuple = (10, 20, 30, 40, 50)

# %%
my_tuple[1:4] #slicing
# Out:
# (20, 30, 40)

# %%
my_tuple[-3:] #negative slicing
# Out:
# (20, 30, 40)

# %% [markdown]
# Q2. Set is the collection of elements which are unique, unordered and mutable.
# Set is implemented using hasing which stores each value once and ignores repeated values.

# %%
my_set = {20, 30, 40, 40, 50, 60, 80, 60} #set removes duplicate values automatically
my_set
# Out:
# {20, 30, 40, 50, 60, 80}

# %%
students = ["Preeti", "Shyam", "Jack", "Hari", "Hari", "Preeti"]
students
# Out:
# ['Preeti', 'Shyam', 'Jack', 'Hari', 'Hari', 'Preeti']

# %%
set(students) #removing dupliacte values from list by converting it into set
# Out:
# {'Hari', 'Jack', 'Preeti', 'Shyam'}

# %% [markdown]
# reversing a list using slicing

# %%
my_list
# Out:
# ['Avi', 'Shyam', 'Krish']

# %%
my_list[::-1] #reversing a list - slicing[start: end : step]
# Out:
# ['Krish', 'Shyam', 'Avi']

# %%
my_list
# Out:
# ['Avi', 'Shyam', 'Krish']

# %% [markdown]
# Dictionary

# %%
student = {
    "name" : "Avi",
    "course" : "IT",
    "age" : 25
 }

# %%
student["name"] #accessing the name
# Out:
# 'Avi'

# %%
student.pop("age") #remioving age
# Out:
# 25

# %%
len(student) #getting length of dictionary
# Out:
# 2

# %%
a = "mytext"

# %%
if a.isalpha(): #isalpha() method checks whether the string is only alphabet or not
    print("valid")
else:
    print("invalid")
# Out:
# valid
