# %%
x = ("key1", "key2", "key3")
y = 0
this_dict = dict.fromkeys(x,y)
this_dict
# Out:
# {'key1': 0, 'key2': 0, 'key3': 0}

# %%
d = ("key1", "key2", "key3")
this_dict = dict.fromkeys(d)
this_dict
# Out:
# {'key1': None, 'key2': None, 'key3': None}

# %%
# loops in dict

# %%
this_dict = {
    "name" : "Avishek",
    "class" : "BDE",
    "year" : 2026
}
this_dict
# Out:
# {'name': 'Avishek', 'class': 'BDE', 'year': 2026}

# %%
for x in this_dict:
    print(this_dict[x])
# Out:
# Avishek
# BDE
# 2026

# %%
for x in this_dict.values():
    print(x)
# Out:
# Avishek
# BDE
# 2026

# %%
for x in this_dict.keys():
    print(x)
# Out:
# name
# class
# year

# %%
for x in this_dict.items():
    print(x)
# Out:
# ('name', 'Avishek')
# ('class', 'BDE')
# ('year', 2026)
